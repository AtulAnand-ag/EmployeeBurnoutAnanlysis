# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
data = pd.read_csv("/employee_burnout_analysis-AI 2.csv")

# %%
data
# Out:
#                     Employee ID Date of Joining  Gender Company Type  \
# 0      fffe32003000360033003200      30-09-2008  Female      Service
# 1          fffe3700360033003500      30-11-2008    Male      Service
# 2      fffe31003300320037003900      10-03-2008  Female      Product
# 3      fffe32003400380032003900      03-11-2008    Male      Service
# 4      fffe31003900340031003600      24-07-2008  Female      Service
# ...                         ...             ...     ...          ...
# 22745  fffe31003500370039003100      30-12-2008  Female      Service
# 22746  fffe33003000350031003800      19-01-2008  Female      Product
# 22747          fffe390032003000      05-11-2008    Male      Service
# 22748  fffe33003300320036003900      10-01-2008  Female      Service
# 22749      fffe3400350031003800      06-01-2008    Male      Product
#
#       WFH Setup Available  Designation  Resource Allocation  \
# 0                      No            2                  3.0
# 1                     Yes            1                  2.0
# 2                     Yes            2                  NaN
# 3                     Yes            1                  1.0
# 4                      No            3                  7.0
# ...                   ...          ...                  ...
# 22745                  No            1                  3.0
# 22746                 Yes            3                  6.0
# 22747                 Yes            3                  7.0
# 22748                  No            2                  5.0
# 22749                  No            3                  6.0
#
#        Mental Fatigue Score  Burn Rate
# 0                       3.8       0.16
# 1                       5.0       0.36
# 2                       5.8       0.49
# 3                       2.6       0.20
# 4                       6.9       0.52
# ...                     ...        ...
# 22745                   NaN       0.41
# 22746                   6.7       0.59
# 22747                   NaN       0.72
# 22748                   5.9       0.52
# 22749                   7.8       0.61
#
# [22750 rows x 9 columns]

# %%
data.head()
# Out:
#                 Employee ID Date of Joining  Gender Company Type  \
# 0  fffe32003000360033003200      30-09-2008  Female      Service
# 1      fffe3700360033003500      30-11-2008    Male      Service
# 2  fffe31003300320037003900      10-03-2008  Female      Product
# 3  fffe32003400380032003900      03-11-2008    Male      Service
# 4  fffe31003900340031003600      24-07-2008  Female      Service
#
#   WFH Setup Available  Designation  Resource Allocation  Mental Fatigue Score  \
# 0                  No            2                  3.0                   3.8
# 1                 Yes            1                  2.0                   5.0
# 2                 Yes            2                  NaN                   5.8
# 3                 Yes            1                  1.0                   2.6
# 4                  No            3                  7.0                   6.9
#
#    Burn Rate
# 0       0.16
# 1       0.36
# 2       0.49
# 3       0.20
# 4       0.52

# %%
data.head(11)
# Out:
#                  Employee ID Date of Joining  Gender Company Type  \
# 0   fffe32003000360033003200      30-09-2008  Female      Service
# 1       fffe3700360033003500      30-11-2008    Male      Service
# 2   fffe31003300320037003900      10-03-2008  Female      Product
# 3   fffe32003400380032003900      03-11-2008    Male      Service
# 4   fffe31003900340031003600      24-07-2008  Female      Service
# 5       fffe3300350037003500      26-11-2008    Male      Product
# 6   fffe33003300340039003100      02-01-2008  Female      Service
# 7   fffe32003600320037003400      31-10-2008  Female      Service
# 8   fffe32003200300034003700      27-12-2008  Female      Service
# 9   fffe31003600320030003200      09-03-2008  Female      Product
# 10  fffe33003100330032003700      16-03-2008    Male      Product
#
#    WFH Setup Available  Designation  Resource Allocation  \
# 0                   No            2                  3.0
# 1                  Yes            1                  2.0
# 2                  Yes            2                  NaN
# 3                  Yes            1                  1.0
# 4                   No            3                  7.0
# 5                  Yes            2                  4.0
# 6                   No            3                  6.0
# 7                  Yes            2                  4.0
# 8                   No            3                  6.0
# 9                   No            3                  6.0
# 10                 Yes            2                  3.0
#
#     Mental Fatigue Score  Burn Rate
# 0                    3.8       0.16
# 1                    5.0       0.36
# 2                    5.8       0.49
# 3                    2.6       0.20
# 4                    6.9       0.52
# 5                    3.6       0.29
# 6                    7.9       0.62
# 7                    4.4       0.33
# 8                    NaN       0.56
# 9                    NaN       0.67
# 10                   5.3       0.50

# %%
data.tail()
# Out:
#                     Employee ID Date of Joining  Gender Company Type  \
# 22745  fffe31003500370039003100      30-12-2008  Female      Service
# 22746  fffe33003000350031003800      19-01-2008  Female      Product
# 22747          fffe390032003000      05-11-2008    Male      Service
# 22748  fffe33003300320036003900      10-01-2008  Female      Service
# 22749      fffe3400350031003800      06-01-2008    Male      Product
#
#       WFH Setup Available  Designation  Resource Allocation  \
# 22745                  No            1                  3.0
# 22746                 Yes            3                  6.0
# 22747                 Yes            3                  7.0
# 22748                  No            2                  5.0
# 22749                  No            3                  6.0
#
#        Mental Fatigue Score  Burn Rate
# 22745                   NaN       0.41
# 22746                   6.7       0.59
# 22747                   NaN       0.72
# 22748                   5.9       0.52
# 22749                   7.8       0.61

# %%
data.tail(11)
# Out:
#                     Employee ID Date of Joining  Gender Company Type  \
# 22739  fffe32003300350034003100      06-02-2008    Male      Service
# 22740  fffe33003300380031003100      05-09-2008  Female      Product
# 22741  fffe31003600350034003800      07-01-2008    Male      Product
# 22742  fffe33003200310039003000      28-07-2008    Male      Product
# 22743      fffe3300390030003600      15-12-2008  Female      Product
# 22744  fffe32003500370033003200      27-05-2008    Male      Product
# 22745  fffe31003500370039003100      30-12-2008  Female      Service
# 22746  fffe33003000350031003800      19-01-2008  Female      Product
# 22747          fffe390032003000      05-11-2008    Male      Service
# 22748  fffe33003300320036003900      10-01-2008  Female      Service
# 22749      fffe3400350031003800      06-01-2008    Male      Product
#
#       WFH Setup Available  Designation  Resource Allocation  \
# 22739                  No            2                  5.0
# 22740                  No            3                  6.0
# 22741                  No            2                  5.0
# 22742                  No            3                  5.0
# 22743                 Yes            1                  3.0
# 22744                  No            3                  7.0
# 22745                  No            1                  3.0
# 22746                 Yes            3                  6.0
# 22747                 Yes            3                  7.0
# 22748                  No            2                  5.0
# 22749                  No            3                  6.0
#
#        Mental Fatigue Score  Burn Rate
# 22739                   8.5       0.67
# 22740                   7.3       0.55
# 22741                   6.0        NaN
# 22742                   8.1       0.69
# 22743                   6.0       0.48
# 22744                   6.2       0.54
# 22745                   NaN       0.41
# 22746                   6.7       0.59
# 22747                   NaN       0.72
# 22748                   5.9       0.52
# 22749                   7.8       0.61

# %%
data["Company Type"].unique()
# Out:
# array(['Service', 'Product'], dtype=object)

# %%
data.isnull().sum()
# Out:
# Employee ID                0
# Date of Joining            0
# Gender                     0
# Company Type               0
# WFH Setup Available        0
# Designation                0
# Resource Allocation     1381
# Mental Fatigue Score    2117
# Burn Rate               1124
# dtype: int64

# %%
data.isnull().values.sum()
# Out:
# 4622

# %%
data.shape
# Out:
# (22750, 9)

# %%
data.describe()
# Out:
#         Designation  Resource Allocation  Mental Fatigue Score     Burn Rate
# count  22750.000000         21369.000000          20633.000000  21626.000000
# mean       2.178725             4.481398              5.728188      0.452005
# std        1.135145             2.047211              1.920839      0.198226
# min        0.000000             1.000000              0.000000      0.000000
# 25%        1.000000             3.000000              4.600000      0.310000
# 50%        2.000000             4.000000              5.900000      0.450000
# 75%        3.000000             6.000000              7.100000      0.590000
# max        5.000000            10.000000             10.000000      1.000000

# %%
data.columns.tolist()
# Out:
# ['Employee ID',
#  'Date of Joining',
#  'Gender',
#  'Company Type',
#  'WFH Setup Available',
#  'Designation',
#  'Resource Allocation',
#  'Mental Fatigue Score',
#  'Burn Rate']

# %%
data.nunique()
# Out:
# Employee ID             22750
# Date of Joining           366
# Gender                      2
# Company Type                2
# WFH Setup Available         2
# Designation                 6
# Resource Allocation        10
# Mental Fatigue Score      101
# Burn Rate                 101
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22750 entries, 0 to 22749
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Employee ID           22750 non-null  object
#  1   Date of Joining       22750 non-null  object
#  2   Gender                22750 non-null  object
#  3   Company Type          22750 non-null  object
#  4   WFH Setup Available   22750 non-null  object
#  5   Designation           22750 non-null  int64
#  6   Resource Allocation   21369 non-null  float64
#  7   Mental Fatigue Score  20633 non-null  float64
#  8   Burn Rate             21626 non-null  float64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 1.6+ MB

# %%
data.isnull()
# Out:
#        Employee ID  Date of Joining  Gender  Company Type  \
# 0            False            False   False         False
# 1            False            False   False         False
# 2            False            False   False         False
# 3            False            False   False         False
# 4            False            False   False         False
# ...            ...              ...     ...           ...
# 22745        False            False   False         False
# 22746        False            False   False         False
# 22747        False            False   False         False
# 22748        False            False   False         False
# 22749        False            False   False         False
#
#        WFH Setup Available  Designation  Resource Allocation  \
# 0                    False        False                False
# 1                    False        False                False
# 2                    False        False                 True
# 3                    False        False                False
# 4                    False        False                False
# ...                    ...          ...                  ...
# 22745                False        False                False
# 22746                False        False                False
# 22747                False        False                False
# 22748                False        False                False
# 22749                False        False                False
#
#        Mental Fatigue Score  Burn Rate
# 0                     False      False
# 1                     False      False
# 2                     False      False
# 3                     False      False
# 4                     False      False
# ...                     ...        ...
# 22745                  True      False
# 22746                 False      False
# 22747                  True      False
# 22748                 False      False
# 22749                 False      False
#
# [22750 rows x 9 columns]

# %%
data.corr(numeric_only=True)['Burn Rate'][:-1]
# Out:
# Designation             0.737556
# Resource Allocation     0.856278
# Mental Fatigue Score    0.944546
# Name: Burn Rate, dtype: float64

# %%
data = data.dropna()

# %%
data.shape
# Out:
# (18590, 9)

# %%
data.dtypes
# Out:
# Employee ID              object
# Date of Joining          object
# Gender                   object
# Company Type             object
# WFH Setup Available      object
# Designation               int64
# Resource Allocation     float64
# Mental Fatigue Score    float64
# Burn Rate               float64
# dtype: object

# %%
data = data.drop('Employee ID', axis = 1)

# %%
print(f"Min date {data['Date of Joining'].min()}")
print(f"Max date {data['Date of Joining'].max()}")
data_month = data.copy()

data_month["Date of Joining"] = data_month['Date of Joining'].astype("datetime64[ns]")
data_month["Date of Joining"].groupby(data_month['Date of Joining'].dt.month).count().plot(kind="bar", xlabel='Month', ylabel="Hired employees")
# Out:
# Min date 01-01-2008
# Max date 31-12-2008
# <Axes: xlabel='Month', ylabel='Hired employees'>

# %%
data_2008 = pd.to_datetime(["2008-01-01"]*len(data))
data["Days"] = data['Date of Joining'].astype("datetime64[ns]").sub(data_2008).dt.days
data.Days
# Out:
# 0        273
# 1        334
# 3         70
# 4        205
# 5        330
#         ...
# 22743    349
# 22744    147
# 22746     18
# 22748    274
# 22749    152
# Name: Days, Length: 18590, dtype: int64

# %%
numeric_data = data.select_dtypes(include=['number'])
correlation = numeric_data.corr()['Burn Rate']
print(correlation)
# Out:
# Designation             0.736412
# Resource Allocation     0.855005
# Mental Fatigue Score    0.944389
# Burn Rate               1.000000
# Days                    0.005502
# Name: Burn Rate, dtype: float64

# %%
data.corr(numeric_only=True)['Burn Rate'][:]
# Out:
# Designation             0.736412
# Resource Allocation     0.855005
# Mental Fatigue Score    0.944389
# Burn Rate               1.000000
# Days                    0.005502
# Name: Burn Rate, dtype: float64

# %%
data = data.drop(['Date of Joining', 'Days'], axis = 1)

# %%
data.head()
# Out:
#    Gender Company Type WFH Setup Available  Designation  Resource Allocation  \
# 0  Female      Service                  No            2                  3.0
# 1    Male      Service                 Yes            1                  2.0
# 3    Male      Service                 Yes            1                  1.0
# 4  Female      Service                  No            3                  7.0
# 5    Male      Product                 Yes            2                  4.0
#
#    Mental Fatigue Score  Burn Rate
# 0                   3.8       0.16
# 1                   5.0       0.36
# 3                   2.6       0.20
# 4                   6.9       0.52
# 5                   3.6       0.29
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_1['Designation'].plot(kind='hist', bins=20, title='Designation')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['Resource Allocation'].plot(kind='hist', bins=20, title='Resource Allocation')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['Mental Fatigue Score'].plot(kind='hist', bins=20, title='Mental Fatigue Score')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_4['Burn Rate'].plot(kind='hist', bins=20, title='Burn Rate')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_5.groupby('Gender').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_6.groupby('Company Type').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_7.groupby('WFH Setup Available').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_8.plot(kind='scatter', x='Designation', y='Resource Allocation', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_9.plot(kind='scatter', x='Resource Allocation', y='Mental Fatigue Score', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_10.plot(kind='scatter', x='Mental Fatigue Score', y='Burn Rate', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_11['Designation'].plot(kind='line', figsize=(8, 4), title='Designation')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_12['Resource Allocation'].plot(kind='line', figsize=(8, 4), title='Resource Allocation')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_13['Mental Fatigue Score'].plot(kind='line', figsize=(8, 4), title='Mental Fatigue Score')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_14['Burn Rate'].plot(kind='line', figsize=(8, 4), title='Burn Rate')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Company Type'].value_counts()
#     for x_label, grp in _df_15.groupby('Gender')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Gender')
# _ = plt.ylabel('Company Type')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['WFH Setup Available'].value_counts()
#     for x_label, grp in _df_16.groupby('Company Type')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Company Type')
# _ = plt.ylabel('WFH Setup Available')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_17['Gender'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_17, x='Designation', y='Gender', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_18['Company Type'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_18, x='Designation', y='Company Type', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_19['WFH Setup Available'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_19, x='Designation', y='WFH Setup Available', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_20['Gender'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_20, x='Resource Allocation', y='Gender', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
data.head()
# Out:
#    Gender Company Type WFH Setup Available  Designation  Resource Allocation  \
# 0  Female      Service                  No            2                  3.0
# 1    Male      Service                 Yes            1                  2.0
# 3    Male      Service                 Yes            1                  1.0
# 4  Female      Service                  No            3                  7.0
# 5    Male      Product                 Yes            2                  4.0
#
#    Mental Fatigue Score  Burn Rate
# 0                   3.8       0.16
# 1                   5.0       0.36
# 3                   2.6       0.20
# 4                   6.9       0.52
# 5                   3.6       0.29

# %%
cat_columns = data.select_dtypes(object).columns

fig, ax = plt.subplots(nrows=1, ncols=len(cat_columns), sharey=True, figsize=(10, 5))

for i, c in enumerate(cat_columns):
    sns.countplot(x=c, data=data, ax=ax[i])

plt.show()

# %%
if all(col in data.columns for col in ['Company Type', 'WFH Setup Available', 'Gender']):
    data = pd.get_dummies(data, columns=['Company Type', 'WFH Setup Available', 'Gender'], drop_first=True)
    data.head()
    encoded_columns = data.columns
else:
    print("Error: One or more of the specified columns are not present in the DataFrame.")
    print(data.columns)

# %%
data
# Out:
#        Designation  Resource Allocation  Mental Fatigue Score  Burn Rate  \
# 0                2                  3.0                   3.8       0.16
# 1                1                  2.0                   5.0       0.36
# 3                1                  1.0                   2.6       0.20
# 4                3                  7.0                   6.9       0.52
# 5                2                  4.0                   3.6       0.29
# ...            ...                  ...                   ...        ...
# 22743            1                  3.0                   6.0       0.48
# 22744            3                  7.0                   6.2       0.54
# 22746            3                  6.0                   6.7       0.59
# 22748            2                  5.0                   5.9       0.52
# 22749            3                  6.0                   7.8       0.61
#
#        Company Type_Service  WFH Setup Available_Yes  Gender_Male
# 0                      True                    False        False
# 1                      True                     True         True
# 3                      True                     True         True
# 4                      True                    False        False
# 5                     False                     True         True
# ...                     ...                      ...          ...
# 22743                 False                     True        False
# 22744                 False                    False         True
# 22746                 False                     True        False
# 22748                  True                    False        False
# 22749                 False                    False         True
#
# [18590 rows x 7 columns]

# %%
y = data['Burn Rate']
X = data.drop('Burn Rate', axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.7, shuffle=True, random_state=1)

scaler = StandardScaler()
scaler.fit(X_train)
# Use the correct index for X_train
X_train = pd.DataFrame(scaler.transform(X_train), index=X_train.index, columns=X_train.columns)
X_test = pd.DataFrame(scaler.transform(X_test), index=X_test.index, columns=X_test.columns)

# %%
X_train
# Out:
#        Designation  Resource Allocation  Mental Fatigue Score  \
# 3249      0.729794             0.733212              0.501849
# 7925      0.729794             0.733212              0.398570
# 16635    -0.155002            -0.730675             -1.925209
# 3456      1.614590             0.733212              1.224802
# 17562     0.729794             0.245250             -0.169465
# ...            ...                  ...                   ...
# 13453     0.729794             1.221175              1.637919
# 21179     0.729794             0.245250             -1.047337
# 6327      0.729794             0.245250              0.088733
# 14933    -0.155002             0.245250              0.708407
# 288      -0.155002             0.245250              1.069884
#
#        Company Type_Service  WFH Setup Available_Yes  Gender_Male
# 3249               0.714251                -1.104601     1.049455
# 7925              -1.400068                 0.905304     1.049455
# 16635              0.714251                -1.104601     1.049455
# 3456              -1.400068                -1.104601    -0.952875
# 17562              0.714251                -1.104601     1.049455
# ...                     ...                      ...          ...
# 13453             -1.400068                 0.905304    -0.952875
# 21179              0.714251                 0.905304     1.049455
# 6327               0.714251                -1.104601     1.049455
# 14933              0.714251                -1.104601     1.049455
# 288               -1.400068                -1.104601    -0.952875
#
# [5577 rows x 6 columns]

# %%
y_train
# Out:
# 3249     0.62
# 7925     0.50
# 16635    0.13
# 3456     0.66
# 17562    0.42
#          ...
# 13453    0.78
# 21179    0.30
# 6327     0.42
# 14933    0.54
# 288      0.57
# Name: Burn Rate, Length: 5577, dtype: float64

# %%
linear_regression_model = LinearRegression()
linear_regression_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print("Linear Regression Model Performance Matrics \n")
y_pred = linear_regression_model.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)

# Calculate RMSE by taking the square root of MSE
rmse = mse**0.5
print("Root Mean Squared Error:", rmse)

mae = mean_absolute_error(y_test, y_pred)
print("Mean Absolute Error:", mae)

r2 = r2_score(y_test, y_pred)
print("R-squared:", r2)
# Out:
# Linear Regression Model Performance Matrics
#
# Mean Squared Error: 0.0031265186703183815
# Root Mean Squared Error: 0.05591528118786833
# Mean Absolute Error: 0.045748186923994995
# R-squared: 0.9199255887706531

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
knn_regressor = KNeighborsRegressor(n_neighbors=5)
knn_regressor.fit(X_train, y_train)
# Out:
# KNeighborsRegressor()

# %%
y_predKnn = knn_regressor.predict(X_test)

# %%
print("Linear Regression Model Performance Matrics \n")

mse = mean_squared_error(y_test, y_predKnn)
print("Mean Squared Error:", mse)

# Calculate RMSE by taking the square root of MSE
rmse = mse**0.5
print("Root Mean Squared Error:", rmse)

mae = mean_absolute_error(y_test, y_predKnn)
print("Mean Absolute Error:", mae)

r2 = r2_score(y_test, y_predKnn)
print("R-squared:", r2)
# Out:
# Linear Regression Model Performance Matrics
#
# Mean Squared Error: 0.0034794236532698073
# Root Mean Squared Error: 0.05898663961669462
# Mean Absolute Error: 0.04694182740336587
# R-squared: 0.9108872103985641
